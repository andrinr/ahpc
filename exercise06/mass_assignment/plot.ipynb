# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
data = np.loadtxt('out_projected.txt', delimiter=' ', unpack=True)
plt.imshow(data, cmap='plasma', interpolation='nearest')

# %%
data = np.loadtxt('out_power.txt', delimiter=' ', unpack=True)
print(data[:,0])
plt.plot(data[:, 1], data[:,0])
# Out:
# [3.57348e+10 2.48561e+07 2.07766e+07 1.48597e+07 1.24735e+07 1.07757e+07
#  8.49728e+06 7.17350e+06 5.94019e+06 5.08029e+06 4.45103e+06 4.13066e+06
#  3.69514e+06 3.30670e+06 2.99638e+06 2.66117e+06 2.47063e+06 2.25719e+06
#  2.05275e+06 1.90779e+06 1.81155e+06 1.68037e+06 1.55277e+06 1.45180e+06
#  1.38026e+06 1.31174e+06 1.23490e+06 1.18142e+06 1.13492e+06 1.09010e+06]
